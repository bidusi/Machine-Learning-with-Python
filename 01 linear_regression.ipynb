# %% [markdown]
# ## Titanic passenger survival rate predictor using linear regression
# Linear regression is one of the most basic forms of machine learning and is used to predict numeric values.
#
# Here, we  use a linear model to predict the survival rate of passangers from the titanic dataset.
#
# This section is based on the following documentation: https://colab.research.google.com/drive/15Cyy2H7nT40sGR7TBN5wBvgTd57mVKay#forceEdit=true&sandboxMode=true&scrollTo=mbdnKlcuMM4u

# %%
from __future__ import absolute_import,division,print_function,unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
#from six.moves import urllib

# %%
import tensorflow._api.v2.feature_column as fc
import tensorflow as tf

# %%
#training data
dftrain = pd.read_csv('train.csv')

#testing data
dftest = pd.read_csv('eval.csv')

y_train=dftrain.pop('survived')
y_test=dftest.pop('survived')

# %%
dftrain.describe()
# Out:
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200

# %%
dftrain.shape
# Out:
# (627, 9)

# %%
dftrain.age.hist(bins=20)
# Out:
# <Axes: >

# %%
dftrain['class'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.concat([dftrain,y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh')
# Out:
# <Axes: ylabel='sex'>

# %%
dftrain.head()
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
cat_cols = ['sex','n_siblings_spouses','parch','class','deck','embark_town','alone']
num_cols = ['age','fare']

# %%
for feature_name in cat_cols:
    vocab = dftrain[feature_name].unique()
    print(feature_name,vocab)
# Out:
# sex ['male' 'female']
# n_siblings_spouses [1 0 3 4 2 5 8]
# parch [0 1 2 5 3 4]
# class ['Third' 'First' 'Second']
# deck ['unknown' 'C' 'G' 'A' 'B' 'D' 'F' 'E']
# embark_town ['Southampton' 'Cherbourg' 'Queenstown' 'unknown']
# alone ['n' 'y']

# %%
feature_cols = []

for feature_name in cat_cols:
    vocab = dftrain[feature_name].unique()
    feature_cols.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocab))

for feature_name in num_cols:
    feature_cols.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))
# Out:
# WARNING:tensorflow:From C:\Users\acer\AppData\Local\Temp\ipykernel_4376\1122477384.py:5: categorical_column_with_vocabulary_list (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
# WARNING:tensorflow:From C:\Users\acer\AppData\Local\Temp\ipykernel_4376\1122477384.py:8: numeric_column (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
print(feature_cols)
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, d
# ...

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df),label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    return input_function

train_input_fn = make_input_fn(dftrain , y_train)
test_input_fn = make_input_fn(dftest, y_test, shuffle=False, num_epochs=1)

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_cols)
# Out:
# WARNING:tensorflow:From C:\Users\acer\AppData\Local\Temp\ipykernel_4376\3809897803.py:1: LinearClassifierV2.__init__ (from tensorflow_estimator.python.estimator.canned.linear) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From c:\Python38\lib\site-packages\tensorflow_estimator\python\estimator\head\head_utils.py:54: BinaryClassHead.__init__ (from tensorflow_estimator.python.estimator.head.binary_class_head) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From c:\Python38\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:944: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# ...

# %%
linear_est.train(train_input_fn)
result = linear_est.evaluate(test_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\Python38\lib\site-packages\keras\src\optimizers\legacy\ftrl.py:173: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\Python38\lib\site-packages\tensorflow_estimator\python\estimator\model_fn.py:250: EstimatorSpec.__new__ (from tensorflow_estimator.python.estimator.model_fn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From c:\Python38\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py:1416: NanTensorHook.__init__ (from tensorflow.python.training.basic_session_run_hooks) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
print(result['accuracy'])
# Out:
# 0.7386364

# %%
result = list(linear_est.predict(test_input_fn))
id = 5
print('Profile of passanger: \n',dftest.loc[id])
print('Survived? (1 if Yes, 0 if No) ',y_test.loc[id])
print('predicted probability of survival is ',result[id]['probabilities'][1])
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\acer\AppData\Local\Temp\tmpndddobzu\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Profile of passanger:
#  sex                       female
# age                         15.0
# n_siblings_spouses             0
# parch                          0
# fare                      8.0292
# class                      Third
# deck                     unknown
# embark_town           Queenstown
# alone                          y
# Name: 5, dtype: object
# Survived? (1 if Yes, 0 if No)  1
# predicted probability of survival is  0.74636394
